# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %%
z = 227.43%7

print(z)
# Out:
# 3.430000000000007

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %%
x = str(22)
y = int(x)+ 12.0
z = int(x) / 3
z = int(z)


print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %%
a = 5
b = '3'

print(a-b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-06b539a0736a> in <module>
#       2 b = '3'
#       3
# ----> 4 print(a-b)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %%
x = 42
y = True
z = not y

if y:
    x = x/2
    y = not y
else:
    x = x*2
    
if x < 42:
    z = not y
    x = not z
else:
    z = not z
    x = x
    
print ('x=', x)
print ('z=', z)
# Out:
# x= False
# z= True

# %% [markdown]
# ![grafik.png](attachment:grafik.png)
# ![grafik-2.png](attachment:grafik-2.png)

# %%
x = 5

while x <= 7:
    print('Yellow')
    x = x + 1
    print('Black')
print('Yellow')
# Out:
# Yellow
# Black
# Yellow
# Black
# Yellow
# Black
# Yellow

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %%
a = 'c'
b = 'x'
b = a + c

print(a + a + b + 'x')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d8e5727af49f> in <module>
#       1 a = 'c'
#       2 b = 'x'
# ----> 3 b = a + c
#       4
#       5 print(a + a + b + 'x')
#
# NameError: name 'c' is not defined

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %%
b = 3
h = 2

volume = (1/3) * b ** 2 * h

print ('Das Volumen ist', volume)
# Out:
# Das Volumen ist 6.0

# %% [markdown]
# ![grafik.png](attachment:grafik.png)

# %%
x = 10

if x > 20:
    print('a')
elif x > 15:
    print('b')
elif x > 10:
    print('c')
else:
    print('d')

if x < 11:
    print('e')
else:
    print('f')
# Out:
# d
# e
